# %%
import csv
import genanki
import requests

# %% [markdown]
# ## Read in the Google Sheet
# `ingest_sheets` reads a manually created vocab list with the columns
# `word_de | word_en | sentence1_id_de | sentence2_id_de` The last column may be empty. The words should be unique. It assumes there's a header.

# %%
def ingest_sheet(filepath_str):
    words = {}
    with open(filepath_str, newline='', encoding='utf-8') as tsvfile:
        tsvreader = csv.reader(tsvfile, delimiter='\t')
        next(tsvreader)  # skip the headers
        for row in tsvreader:
            word_de = row[0]
            word_en = row[1]
            sentence1_id_de = row[2]
            sentence2_id_de = row[3]
            words[word_de] = {'word_en': word_en,
                              'sentence1_id_de': sentence1_id_de,
                              'sentence2_id_de': sentence2_id_de}
    return words

# %%
vocab = ingest_sheet('./NW_7_Days-and-times.tsv')

# %%
vocab
# Out:
# {'der Arzt, die Ärzte': {'word_en': 'doctor (male)',
#   'sentence1_id_de': '458886',
#   'sentence2_id_de': ''},
#  'die Ärztin, die Ärztinnen': {'word_en': 'doctor (female)',
#   'sentence1_id_de': '428477',
#   'sentence2_id_de': ''},
#  'der Babysitter, die Babysitter': {'word_en': 'babysitter (male)',
#   'sentence1_id_de': '3751325',
#   'sentence2_id_de': ''},
#  'die Babysitterin, die Babysitterinnen': {'word_en': 'babysitter (female)',
#   'sentence1_id_de': '8074468',
#   'sentence2_id_de': ''},
#  'beginnen': {'word_en': 'to begin; to start',
#   'sentence1_id_de': '722917',
#   'sentence2_id_de': ''},
#  'krank': {'word_en': 'sick; ill',
#   'sentence1_id_de': '722917',
#   'sentence2_id_de': ''},
#  'die Lösung, die Lösungen': {'word_en': 'solution',
#   'sentence1_id_de': '1205',
#   'sentence2_id_de': ''},
#  'die Mittagspause, die Mittagspausen': {'word_en': 'lunch break',
#   'sentence1_id_de': '7552388',
#   'sentence2_id_de': ''},
#  'die Schule, die Schulen': {'word_en': 'school',
#   'sentence1_id_de': '135753',
#   'sentence2_id_de': ''},
#  'der Tag, die Tage': {'word_en': 'day',
#   'sentence1_id_de': '454009',
#   'sentence2_id_de': ''},
#  'der Termin, die Termine': {'word_en': 'appointment',
#   'sentence1_id_de': '477555',
#   'sentence2_id_de': ''},
#  'das Training, die Trainings': {'word_en': 'training; workout; practice',
#   'sentence1_id_de': '1166392',
#   'sentence2_id_de': ''},
#  'die Uni, die Unis': {'word_en': 'University; college',
#   'sentence1_id_de': '8493305',
#   'sentence2_id_de': ''},
#  'wann': {'word_en': 'when',
#   'sentence1_id_de': '766384',
#   'sentence2_id_de': ''}}

# %% [markdown]
# ## Add the Tatoeba data
# For each word, find the Tatoeba sentence it links to. Get the text and the audio.
# What order?
#
# Not all German sentences have translations.
#
# Not all German sentences have audio.
#
# So get the text of the German sentence first.
#
# Then check for translations.
#
# Then check for audio.

# %% [markdown]
# ### Get the German sentences from the sentence_id

# %%
SENTENCES_DE_PATH = './deu_sentences.tsv'

# %%
def ingest_tsv(filepath_str):
    with open(filepath_str, encoding='utf-8-sig', newline='') as f:
        tsvreader = csv.reader(f, delimiter='\t')
        data = [row for row in tsvreader]
    return data

# %%
def get_sentence_from_id(sentence_id, tsv_data):
    for xs in tsv_data:
        if xs[0] == sentence_id:
            return xs[2]
    return ''

# %%
sentences_de = ingest_tsv(SENTENCES_DE_PATH)

# %%
def validate_id(sentence_id, sentences_data):
    for x in sentences_data:
        if not any([x[0] for x in sentences_data if x[0] == sentence_id]):
            print(f'Could not find sentence with id {sentence_id} in data')
            raise AssertionError
        else:
            return None

# %%
for word in vocab:
    sentence1_id = vocab[word]['sentence1_id_de']
    validate_id(sentence1_id, sentences_de)
    sentence2_id = vocab[word]['sentence2_id_de']
    if sentence2_id:
        validate_id(sentence2_id, sentences_de)

# %%
for word in vocab:
    sentence1_id = vocab[word]['sentence1_id_de']
    sentence1_text = get_sentence_from_id(sentence1_id, sentences_de)
    vocab[word]['sentence1_text'] = sentence1_text
    
    sentence2_id = vocab[word]['sentence2_id_de']
    sentence2_text = get_sentence_from_id(sentence2_id, sentences_de)
    vocab[word]['sentence2_text'] = sentence2_text

# %%
vocab
# Out:
# {'der Arzt, die Ärzte': {'word_en': 'doctor (male)',
#   'sentence1_id_de': '458886',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ist sein Vater Arzt?',
#   'sentence2_text': ''},
#  'die Ärztin, die Ärztinnen': {'word_en': 'doctor (female)',
#   'sentence1_id_de': '428477',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ist sie Ärztin?',
#   'sentence2_text': ''},
#  'der Babysitter, die Babysitter': {'word_en': 'babysitter (male)',
#   'sentence1_id_de': '3751325',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ich benötige keinen Babysitter.',
#   'sentence2_text': ''},
#  'die Babysitterin, die Babysitterinnen': {'word_en': 'babysitter (female)',
#   'sentence1_id_de': '8074468',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Als Jugendliche jobbte Maria als Babysitterin.',
#   'sentence2_text': ''},
#  'beginnen': {'word_en': 'to begin; to start',
#   'sentence1_id_de': '722917',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Sollen wir beginnen?',
#   'sentence2_text': ''},
#  'krank': {'word_en': 'sick; ill',
#   'sentence1_id_de': '722917',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Sollen wir beginnen?',
#   'sentence2_text': ''},
#  'die Lösung, die Lösungen': {'word_en': 'solution',
#   'sentence1_id_de': '1205',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Es gibt keine Lösung.',
#   'sentence2_text': ''},
#  'die Mittagspause, die Mittagspausen': {'word_en': 'lunch break',
#   'sentence1_id_de': '7552388',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Meine Mittagspause ist fast vorbei.',
#   'sentence2_text': ''},
#  'die Schule, die Schulen': {'word_en': 'school',
#   'sentence1_id_de': '135753',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Das ist unsere Schule.',
#   'sentence2_text': ''},
#  'der Tag, die Tage': {'word_en': 'day',
#   'sentence1_id_de': '454009',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Die Tage werden länger.',
#   'sentence2_text': ''},
#  'der Termin, die Termine': {'word_en': 'appointment',
#   'sentence1_id_de': '477555',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ich habe einen Termin beim Arzt.',
#   'sentence2_text': ''},
#  'das Training, die Trainings': {'word_en': 'training; workout; practice',
#   'sentence1_id_de': '1166392',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Rennen ist ein gutes Training.',
#   'sentence2_text': ''},
#  'die Uni, die Unis': {'word_en': 'University; college',
#   'sentence1_id_de': '8493305',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Wo ist eure Uni?',
#   'sentence2_text': ''},
#  'wann': {'word_en': 'when',
#   'sentence1_id_de': '766384',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Wann arbeitest du?',
#   'sentence2_text': ''}}

# %% [markdown]
# ### Process the translations

# %%
PAIRS_FILEPATH = './Sentence pairs in German-English - 2024-12-13.tsv'

# %%
pairs_data = ingest_tsv(PAIRS_FILEPATH)

# %%
for word in vocab:
    sentence1_rows = [row for row in pairs_data if row[0] == vocab[word]['sentence1_id_de']]
    if sentence1_rows:
        sentence1_de = sentence1_rows[0][1]
        # Next line, take 3 English translations max
        sentence1_translations = [xs[3] for xs in sentence1_rows][:3]
        for i, translation in zip([1, 2, 3], sentence1_translations):
            vocab[word][f'translation{i}_en'] = translation

# %%
vocab
# Out:
# {'der Arzt, die Ärzte': {'word_en': 'doctor (male)',
#   'sentence1_id_de': '458886',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ist sein Vater Arzt?',
#   'sentence2_text': '',
#   'translation1_en': 'Is his father a doctor?'},
#  'die Ärztin, die Ärztinnen': {'word_en': 'doctor (female)',
#   'sentence1_id_de': '428477',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ist sie Ärztin?',
#   'sentence2_text': '',
#   'translation1_en': 'Is she a doctor?'},
#  'der Babysitter, die Babysitter': {'word_en': 'babysitter (male)',
#   'sentence1_id_de': '3751325',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ich benötige keinen Babysitter.',
#   'sentence2_text': ''},
#  'die Babysitterin, die Babysitterinnen': {'word_en': 'babysitter (female)',
#   'sentence1_id_de': '8074468',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Als Jugendliche jobbte Maria als Babysitterin.',
#   'sentence2_text': '',
#   'translation1_en': 'Mary worked as a babysitter when she was a teenager.'},
#  'beginnen': {'word_en': 'to begin; to start',
#   'sentence1_id_de': '722917',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Sollen wir beginnen?',
#   'sentence2_text': '',
#   'translation1_en': 'Shall we begin?',
#   'translation2_en': 'Shall we start?'},
#  'krank': {'word_en': 'sick; ill',
#   'sentence1_id_de': '722917',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Sollen wir beginnen?',
#   'sentence2_text': '',
#   'translation1_en': 'Shall we begin?',
#   'translation2_en': 'Shall we start?'},
#  'die Lösung, die Lösungen': {'word_en': 'solution',
#   'sentence1_id_de': '1205',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Es gibt keine Lösung.',
#   'sentence2_text': '',
#   'translation1_en': "There isn't any solution.",
#   'translation2_en': 'There is no solution.'},
#  'die Mittagspause, die Mittagspausen': {'word_en': 'lunch break',
#   'sentence1_id_de': '7552388',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Meine Mittagspause ist fast vorbei.',
#   'sentence2_text': '',
#   'translation1_en': "My lunch break's almost over."},
#  'die Schule, die Schulen': {'word_en': 'school',
#   'sentence1_id_de': '135753',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Das ist unsere Schule.',
#   'sentence2_text': '',
#   'translation1_en': 'That is our school.'},
#  'der Tag, die Tage': {'word_en': 'day',
#   'sentence1_id_de': '454009',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Die Tage werden länger.',
#   'sentence2_text': '',
#   'translation1_en': 'The days are growing longer.',
#   'translation2_en': 'The days are getting longer.'},
#  'der Termin, die Termine': {'word_en': 'appointment',
#   'sentence1_id_de': '477555',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ich habe einen Termin beim Arzt.',
#   'sentence2_text': '',
#   'translation1_en': 'I have an appointment with the doctor.',
#   'translation2_en': "I have a doctor's appointment.",
#   'translation3_en': "I've got a doctor's appointment."},
#  'das Training, die Trainings': {'word_en': 'training; workout; practice',
#   'sentence1_id_de': '1166392',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Rennen ist ein gutes Training.',
#   'sentence2_text': ''},
#  'die Uni, die Unis': {'word_en': 'University; college',
#   'sentence1_id_de': '8493305',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Wo ist eure Uni?',
#   'sentence2_text': '',
#   'translation1_en': "Where's your university?",
#   'translation2_en': "Where's your uni?"},
#  'wann': {'word_en': 'when',
#   'sentence1_id_de': '766384',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Wann arbeitest du?',
#   'sentence2_text': '',
#   'translation1_en': 'When do you work?'}}

# %% [markdown]
# ### Get the audio id
# For the sentences with audio

# %%
AUDIO_SENTENCES_PATH = './sentences_with_audio.csv'

# %%
audio_data = ingest_tsv(AUDIO_SENTENCES_PATH)

# %%
audio_data
# Out:
# [['61', '1', 'fucongcong', '', ''],
#  ['68', '2', 'fucongcong', '', ''],
#  ['78', '754915', 'mramosch', '', ''],
#  ['85',
#   '566395',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['88',
#   '592881',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['91', '754916', 'mramosch', '', ''],
#  ['99', '758277', 'mramosch', '', ''],
#  ['104', '395121', 'Oblomov', '', ''],
#  ['110', '3', 'BraveSentry', '', ''],
#  ['113', '395120', 'Oblomov', '', ''],
#  ['119',
#   '566396',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['120',
#   '790509',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['122', '4', 'BraveSentry', '', ''],
#  ['125', '5', 'BraveSentry', '', ''],
#  ['127', '6', 'BraveSentry', '', ''],
#  ['128', '7', 'BraveSentry', '', ''],
#  ['129', '8', 'BraveSentry', '', ''],
#  ['130', '9', 'BraveSentry', '', ''],
#  ['131', '10', 'BraveSentry', '', ''],
#  ['132', '11', 'BraveSentry', '', ''],
#  ['133', '12', 'BraveSentry', '', ''],
#  ['135', '13', 'BraveSentry', '', ''],
#  ['136', '14', 'BraveSentry', '', ''],
#  ['137', '15', 'BraveSentry', '', ''],
#  ['138', '16', 'BraveSentry', '', ''],
#  ['140', '17', 'BraveSentry', '', ''],
#  ['141', '18', 'BraveSentry', '', ''],
#  ['142', '19', 'BraveSentry', '', ''],
#  ['143', '20', 'BraveSentry', '', ''],
#  ['145', '21', 'BraveSentry', '', ''],
#  ['148', '22', 'BraveSentry', '', ''],
#  ['149', '23', 'BraveSentry', '', ''],
#  ['150', '24', 'BraveSentry', '', ''],
#  ['153', '25', 'BraveSentry', '', ''],
#  ['154', '26', 'BraveSentry', '', ''],
#  ['157', '27', 'BraveSentry', '', ''],
#  ['158', '28', 'BraveSentry', '', ''],
#  ['160', '29', 'BraveSentry', '', ''],
#  ['163', '30', 'BraveSentry', '', ''],
#  ['167', '31', 'BraveSentry', '', ''],
#  ['168', '32', 'BraveSentry', '', ''],
#  ['169', '33', 'BraveSentry', '', ''],
#  ['170', '395119', 'Oblomov', '', ''],
#  ['172', '34', 'BraveSentry', '', ''],
#  ['175', '35', 'BraveSentry', '', ''],
#  ['181', '36', 'BraveSentry', '', ''],
#  ['182', '37', 'BraveSentry', '', ''],
#  ['183', '38', 'BraveSentry', '', ''],
#  ['185', '39', 'BraveSentry', '', ''],
#  ['188', '40', 'gretelen', 'CC BY-NC 4.0', ''],
#  ['189', '41', 'BraveSentry', '', ''],
#  ['190', '42', 'BraveSentry', '', ''],
#  ['192', '43', 'BraveSentry', '', ''],
#  ['193', '44', 'BraveSentry', '', ''],
#  ['194', '45', 'BraveSentry', '', ''],
#  ['197', '46', 'BraveSentry', '', ''],
#  ['199', '47', 'BraveSentry', '', ''],
#  ['205',
#   '566397',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['207', '48', 'gretelen', 'CC BY-NC 4.0', ''],
#  ['210',
#   '700907',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['223', '395118', 'Oblomov', '', ''],
#  ['224', '49', 'BraveSentry', '', ''],
#  ['226', '50', 'BraveSentry', '', ''],
#  ['227', '51', 'BraveSentry', '', ''],
#  ['228', '52', 'BraveSentry', '', ''],
#  ['229', '53', 'BraveSentry', '', ''],
#  ['232', '54', 'BraveSentry', '', ''],
#  ['233', '55', 'BraveSentry', '', ''],
#  ['235', '56', 'BraveSentry', '', ''],
#  ['237', '57', 'BraveSentry', '', ''],
#  ['238', '58', 'BraveSentry', '', ''],
#  ['239', '59', 'BraveSentry', '', ''],
#  ['240', '60', 'BraveSentry', '', ''],
#  ['241', '61', 'BraveSentry', '', ''],
#  ['243', '62', 'Inego', 'CC BY 4.0', ''],
#  ['244', '469753', 'moskytoo', 'CC BY-NC 4.0', ''],
#  ['245', '63', 'BraveSentry', '', ''],
#  ['246', '64', 'BraveSentry', '', ''],
#  ['247', '65', 'gretelen', 'CC BY-NC 4.0', ''],
#  ['248', '66', 'BraveSentry', '', ''],
#  ['249', '67', 'BraveSentry', '', ''],
#  ['250', '68', 'BraveSentry', '', ''],
#  ['251', '69', 'BraveSentry', '', ''],
#  ['252', '70', 'BraveSentry', '', ''],
#  ['253', '71', 'BraveSentry', '', ''],
#  ['254', '72', 'BraveSentry', '', ''],
#  ['256', '73', 'BraveSentry', '', ''],
#  ['258', '74', 'BraveSentry', '', ''],
#  ['261', '75', 'BraveSentry', '', ''],
#  ['267', '76', 'BraveSentry', '', ''],
#  ['268', '77', 'BraveSentry', '', ''],
#  ['269', '78', 'BraveSentry', '', ''],
#  ['271', '79', 'BraveSentry', '', ''],
#  ['272', '80', 'BraveSentry', '', ''],
#  ['273', '81', 'BraveSentry', '', ''],
#  ['274', '82', 'BraveSentry', '', ''],
#  ['275', '83', 'BraveSentry', '', ''],
#  ['276', '84', 'BraveSentry', '', ''],
#  ['277', '85', 'BraveSentry', '', ''],
#  ['279', '86', 'BraveSentry', '', ''],
#  ['280', '87', 'BraveSentry', '', ''],
#  ['281', '88', 'BraveSentry', '', ''],
#  ['282', '89', 'BraveSentry', '', ''],
#  ['283', '90', 'BraveSentry', '', ''],
#  ['284',
#   '566398',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['285', '91', 'gretelen', 'CC BY-NC 4.0', ''],
#  ['286', '92', 'BraveSentry', '', ''],
#  ['287', '93', 'BraveSentry', '', ''],
#  ['289', '94', 'BraveSentry', '', ''],
#  ['292', '95', 'BraveSentry', '', ''],
#  ['293', '96', 'BraveSentry', '', ''],
#  ['294', '97', 'BraveSentry', '', ''],
#  ['296', '98', 'BraveSentry', '', ''],
#  ['298', '100', 'BraveSentry', '', ''],
#  ['299', '101', 'BraveSentry', '', ''],
#  ['300', '102', 'BraveSentry', '', ''],
#  ['301', '103', 'BraveSentry', '', ''],
#  ['303', '104', 'BraveSentry', '', ''],
#  ['304', '105', 'BraveSentry', '', ''],
#  ['305', '398550', 'BraveSentry', '', ''],
#  ['306', '107', 'BraveSentry', '', ''],
#  ['307', '108', 'BraveSentry', '', ''],
#  ['308', '351638', 'BraveSentry', '', ''],
#  ['313', '110', 'BraveSentry', '', ''],
#  ['314', '111', 'BraveSentry', '', ''],
#  ['315', '112', 'BraveSentry', '', ''],
#  ['316', '565507', 'BraveSentry', '', ''],
#  ['317', '536967', 'BraveSentry', '', ''],
#  ['318', '115', 'BraveSentry', '', ''],
#  ['319', '116', 'BraveSentry', '', ''],
#  ['320', '117', 'BraveSentry', '', ''],
#  ['321', '673440', 'BraveSentry', '', ''],
#  ['322', '119', 'BraveSentry', '', ''],
#  ['323', '120', 'BraveSentry', '', ''],
#  ['325', '121', 'BraveSentry', '', ''],
#  ['327', '122', 'BraveSentry', '', ''],
#  ['328', '123', 'BraveSentry', '', ''],
#  ['329', '124', 'BraveSentry', '', ''],
#  ['331', '125', 'BraveSentry', '', ''],
#  ['334', '126', 'BraveSentry', '', ''],
#  ['336', '127', 'BraveSentry', '', ''],
#  ['337', '128', 'BraveSentry', '', ''],
#  ['338', '129', 'BraveSentry', '', ''],
#  ['339', '130', 'BraveSentry', '', ''],
#  ['341', '131', 'BraveSentry', '', ''],
#  ['342', '132', 'BraveSentry', '', ''],
#  ['343', '133', 'BraveSentry', '', ''],
#  ['344', '134', 'BraveSentry', '', ''],
#  ['345', '135', 'BraveSentry', '', ''],
#  ['346', '334081', 'BraveSentry', '', ''],
#  ['347', '137', 'BraveSentry', '', ''],
#  ['348', '138', 'BraveSentry', '', ''],
#  ['349', '139', 'BraveSentry', '', ''],
#  ['350', '140', 'BraveSentry', '', ''],
#  ['354', '141', 'BraveSentry', '', ''],
#  ['355', '142', 'BraveSentry', '', ''],
#  ['356', '143', 'BraveSentry', '', ''],
#  ['360', '144', 'BraveSentry', '', ''],
#  ['361', '145', 'BraveSentry', '', ''],
#  ['363', '146', 'BraveSentry', '', ''],
#  ['364', '147', 'BraveSentry', '', ''],
#  ['365', '148', 'BraveSentry', '', ''],
#  ['367', '149', 'BraveSentry', '', ''],
#  ['368',
#   '592882',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['369', '150', 'BraveSentry', '', ''],
#  ['370', '151', 'BraveSentry', '', ''],
#  ['371', '152', 'gretelen', 'CC BY-NC 4.0', ''],
#  ['372', '153', 'BraveSentry', '', ''],
#  ['373', '154', 'BraveSentry', '', ''],
#  ['374', '155', 'BraveSentry', '', ''],
#  ['376', '156', 'BraveSentry', '', ''],
#  ['377', '157', 'BraveSentry', '', ''],
#  ['378', '158', 'BraveSentry', '', ''],
#  ['381', '159', 'BraveSentry', '', ''],
#  ['382', '160', 'BraveSentry', '', ''],
#  ['383', '161', 'BraveSentry', '', ''],
#  ['386',
#   '790510',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['387', '162', 'BraveSentry', '', ''],
#  ['388', '163', 'BraveSentry', '', ''],
#  ['389', '164', 'BraveSentry', '', ''],
#  ['391', '165', 'BraveSentry', '', ''],
#  ['392', '166', 'BraveSentry', '', ''],
#  ['396', '167', 'BraveSentry', '', ''],
#  ['399', '168', 'BraveSentry', '', ''],
#  ['400', '169', 'BraveSentry', '', ''],
#  ['401', '170', 'BraveSentry', '', ''],
#  ['402', '171', 'BraveSentry', '', ''],
#  ['403', '172', 'BraveSentry', '', ''],
#  ['404', '173', 'BraveSentry', '', ''],
#  ['405', '174', 'BraveSentry', '', ''],
#  ['408', '175', 'BraveSentry', '', ''],
#  ['410', '176', 'BraveSentry', '', ''],
#  ['411', '177', 'BraveSentry', '', ''],
#  ['413', '178', 'BraveSentry', '', ''],
#  ['414', '179', 'BraveSentry', '', ''],
#  ['416', '180', 'BraveSentry', '', ''],
#  ['417', '181', 'BraveSentry', '', ''],
#  ['419', '182', 'BraveSentry', '', ''],
#  ['421', '183', 'BraveSentry', '', ''],
#  ['422', '184', 'BraveSentry', '', ''],
#  ['423', '185', 'BraveSentry', '', ''],
#  ['424', '186', 'BraveSentry', '', ''],
#  ['425', '187', 'BraveSentry', '', ''],
#  ['428', '188', 'BraveSentry', '', ''],
#  ['429', '189', 'BraveSentry', '', ''],
#  ['430', '190', 'BraveSentry', '', ''],
#  ['431', '191', 'BraveSentry', '', ''],
#  ['433', '192', 'BraveSentry', '', ''],
#  ['434', '193', 'BraveSentry', '', ''],
#  ['435', '194', 'BraveSentry', '', ''],
#  ['436', '195', 'BraveSentry', '', ''],
#  ['437', '196', 'BraveSentry', '', ''],
#  ['438', '197', 'BraveSentry', '', ''],
#  ['439', '198', 'BraveSentry', '', ''],
#  ['440', '199', 'BraveSentry', '', ''],
#  ['442', '200', 'BraveSentry', '', ''],
#  ['443', '201', 'BraveSentry', '', ''],
#  ['444', '202', 'BraveSentry', '', ''],
#  ['446', '203', 'BraveSentry', '', ''],
#  ['447', '204', 'BraveSentry', '', ''],
#  ['448', '205', 'BraveSentry', '', ''],
#  ['449', '206', 'BraveSentry', '', ''],
#  ['450', '207', 'BraveSentry', '', ''],
#  ['451', '208', 'BraveSentry', '', ''],
#  ['452', '209', 'BraveSentry', '', ''],
#  ['453', '210', 'BraveSentry', '', ''],
#  ['454', '211', 'BraveSentry', '', ''],
#  ['455', '212', 'BraveSentry', '', ''],
#  ['457', '213', 'BraveSentry', '', ''],
#  ['458', '214', 'BraveSentry', '', ''],
#  ['459', '215', 'BraveSentry', '', ''],
#  ['460', '216', 'BraveSentry', '', ''],
#  ['464', '217', 'BraveSentry', '', ''],
#  ['465', '218', 'BraveSentry', '', ''],
#  ['466', '219', 'BraveSentry', '', ''],
#  ['467', '220', 'BraveSentry', '', ''],
#  ['468', '754917', 'mramosch', '', ''],
#  ['469', '221', 'BraveSentry', '', ''],
#  ['470', '222', 'BraveSentry', '', ''],
#  ['472', '223', 'BraveSentry', '', ''],
#  ['473', '224', 'BraveSentry', '', ''],
#  ['476', '225', 'BraveSentry', '', ''],
#  ['480', '226', 'gretelen', 'CC BY-NC 4.0', ''],
#  ['481', '227', 'BraveSentry', '', ''],
#  ['483', '228', 'BraveSentry', '', ''],
#  ['485', '229', 'BraveSentry', '', ''],
#  ['486', '230', 'BraveSentry', '', ''],
#  ['492', '231', 'BraveSentry', '', ''],
#  ['494', '232', 'BraveSentry', '', ''],
#  ['495', '233', 'BraveSentry', '', ''],
#  ['497', '234', 'BraveSentry', '', ''],
#  ['498', '235', 'BraveSentry', '', ''],
#  ['500', '236', 'BraveSentry', '', ''],
#  ['501', '237', 'BraveSentry', '', ''],
#  ['503', '238', 'BraveSentry', '', ''],
#  ['504', '239', 'BraveSentry', '', ''],
#  ['505', '240', 'BraveSentry', '', ''],
#  ['506', '241', 'BraveSentry', '', ''],
#  ['507', '242', 'BraveSentry', '', ''],
#  ['509', '243', 'BraveSentry', '', ''],
#  ['511',
#   '566399',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['516', '244', 'BraveSentry', '', ''],
#  ['517', '245', 'BraveSentry', '', ''],
#  ['518', '246', 'BraveSentry', '', ''],
#  ['519', '247', 'BraveSentry', '', ''],
#  ['521', '248', 'BraveSentry', '', ''],
#  ['522', '249', 'BraveSentry', '', ''],
#  ['523', '250', 'BraveSentry', '', ''],
#  ['524', '251', 'BraveSentry', '', ''],
#  ['527', '252', 'BraveSentry', '', ''],
#  ['528', '253', 'BraveSentry', '', ''],
#  ['530', '254', 'BraveSentry', '', ''],
#  ['531', '255', 'BraveSentry', '', ''],
#  ['532', '256', 'BraveSentry', '', ''],
#  ['537', '257', 'BraveSentry', '', ''],
#  ['538', '258', 'BraveSentry', '', ''],
#  ['541', '259', 'BraveSentry', '', ''],
#  ['544', '260', 'BraveSentry', '', ''],
#  ['545', '261', 'BraveSentry', '', ''],
#  ['548', '262', 'BraveSentry', '', ''],
#  ['550', '263', 'BraveSentry', '', ''],
#  ['551', '264', 'BraveSentry', '', ''],
#  ['553', '265', 'BraveSentry', '', ''],
#  ['554', '266', 'BraveSentry', '', ''],
#  ['555', '267', 'BraveSentry', '', ''],
#  ['556', '268', 'BraveSentry', '', ''],
#  ['557', '269', 'BraveSentry', '', ''],
#  ['559', '270', 'BraveSentry', '', ''],
#  ['560', '271', 'BraveSentry', '', ''],
#  ['561', '272', 'BraveSentry', '', ''],
#  ['562', '273', 'BraveSentry', '', ''],
#  ['564', '274', 'BraveSentry', '', ''],
#  ['566', '275', 'BraveSentry', '', ''],
#  ['567', '276', 'BraveSentry', '', ''],
#  ['568', '277', 'BraveSentry', '', ''],
#  ['570', '278', 'BraveSentry', '', ''],
#  ['572', '279', 'BraveSentry', '', ''],
#  ['573', '280', 'BraveSentry', '', ''],
#  ['574', '281', 'BraveSentry', '', ''],
#  ['575', '282', 'BraveSentry', '', ''],
#  ['576', '283', 'BraveSentry', '', ''],
#  ['578', '284', 'BraveSentry', '', ''],
#  ['583', '285', 'BraveSentry', '', ''],
#  ['584', '286', 'BraveSentry', '', ''],
#  ['585', '660982', 'BraveSentry', '', ''],
#  ['586', '288', 'BraveSentry', '', ''],
#  ['587', '289', 'BraveSentry', '', ''],
#  ['589', '290', 'BraveSentry', '', ''],
#  ['590', '291', 'BraveSentry', '', ''],
#  ['591', '292', 'BraveSentry', '', ''],
#  ['592', '395117', 'Oblomov', '', ''],
#  ['594', '293', 'BraveSentry', '', ''],
#  ['595', '294', 'BraveSentry', '', ''],
#  ['596', '295', 'BraveSentry', '', ''],
#  ['597', '296', 'BraveSentry', '', ''],
#  ['598', '297', 'BraveSentry', '', ''],
#  ['599', '298', 'BraveSentry', '', ''],
#  ['602', '299', 'BraveSentry', '', ''],
#  ['604', '300', 'BraveSentry', '', ''],
#  ['605', '301', 'BraveSentry', '', ''],
#  ['606', '302', 'BraveSentry', '', ''],
#  ['608', '303', 'BraveSentry', '', ''],
#  ['609', '304', 'BraveSentry', '', ''],
#  ['610', '305', 'BraveSentry', '', ''],
#  ['612', '306', 'BraveSentry', '', ''],
#  ['613',
#   '695435',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['614', '307', 'BraveSentry', '', ''],
#  ['616', '308', 'BraveSentry', '', ''],
#  ['617', '309', 'BraveSentry', '', ''],
#  ['618', '310', 'BraveSentry', '', ''],
#  ['619', '311', 'BraveSentry', '', ''],
#  ['620', '312', 'BraveSentry', '', ''],
#  ['621', '313', 'BraveSentry', '', ''],
#  ['622', '314', 'BraveSentry', '', ''],
#  ['623', '315', 'BraveSentry', '', ''],
#  ['626', '317', 'BraveSentry', '', ''],
#  ['627', '318', 'BraveSentry', '', ''],
#  ['628', '319', 'BraveSentry', '', ''],
#  ['629', '320', 'BraveSentry', '', ''],
#  ['631', '321', 'BraveSentry', '', ''],
#  ['632', '322', 'BraveSentry', '', ''],
#  ['633', '323', 'BraveSentry', '', ''],
#  ['634', '324', 'BraveSentry', '', ''],
#  ['635', '325', 'BraveSentry', '', ''],
#  ['636', '326', 'BraveSentry', '', ''],
#  ['637', '327', 'BraveSentry', '', ''],
#  ['638', '328', 'BraveSentry', '', ''],
#  ['641', '330', 'BraveSentry', '', ''],
#  ['643', '331', 'BraveSentry', '', ''],
#  ['644', '332', 'BraveSentry', '', ''],
#  ['645', '333', 'BraveSentry', '', ''],
#  ['646', '334', 'BraveSentry', '', ''],
#  ['648', '335', 'BraveSentry', '', ''],
#  ['649', '336', 'BraveSentry', '', ''],
#  ['650', '337', 'BraveSentry', '', ''],
#  ['651', '338', 'BraveSentry', '', ''],
#  ['652', '339', 'BraveSentry', '', ''],
#  ['653', '340', 'BraveSentry', '', ''],
#  ['655', '341', 'BraveSentry', '', ''],
#  ['656', '342', 'BraveSentry', '', ''],
#  ['657', '343', 'BraveSentry', '', ''],
#  ['658', '344', 'BraveSentry', '', ''],
#  ['660', '345', 'BraveSentry', '', ''],
#  ['662', '346', 'BraveSentry', '', ''],
#  ['663', '347', 'BraveSentry', '', ''],
#  ['664', '348', 'BraveSentry', '', ''],
#  ['669', '349', 'BraveSentry', '', ''],
#  ['670', '350', 'BraveSentry', '', ''],
#  ['671',
#   '566802',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['673', '351', 'BraveSentry', '', ''],
#  ['674', '352', 'BraveSentry', '', ''],
#  ['675',
#   '566803',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['677', '353', 'BraveSentry', '', ''],
#  ['678', '354', 'BraveSentry', '', ''],
#  ['680', '355', 'BraveSentry', '', ''],
#  ['682', '356', 'BraveSentry', '', ''],
#  ['684', '357', 'BraveSentry', '', ''],
#  ['685', '358', 'BraveSentry', '', ''],
#  ['686', '359', 'BraveSentry', '', ''],
#  ['687', '360', 'BraveSentry', '', ''],
#  ['688', '361', 'BraveSentry', '', ''],
#  ['689', '362', 'BraveSentry', '', ''],
#  ['690', '363', 'BraveSentry', '', ''],
#  ['695', '364', 'BraveSentry', '', ''],
#  ['696', '365', 'BraveSentry', '', ''],
#  ['698', '366', 'BraveSentry', '', ''],
#  ['699', '367', 'BraveSentry', '', ''],
#  ['700', '368', 'BraveSentry', '', ''],
#  ['701', '369', 'BraveSentry', '', ''],
#  ['703', '370', 'BraveSentry', '', ''],
#  ['704', '754918', 'mramosch', '', ''],
#  ['705', '371', 'BraveSentry', '', ''],
#  ['707', '372', 'BraveSentry', '', ''],
#  ['708', '373', 'BraveSentry', '', ''],
#  ['709', '374', 'BraveSentry', '', ''],
#  ['711', '375', 'BraveSentry', '', ''],
#  ['712', '376', 'BraveSentry', '', ''],
#  ['714', '377', 'BraveSentry', '', ''],
#  ['715', '378', 'BraveSentry', '', ''],
#  ['717', '379', 'BraveSentry', '', ''],
#  ['718', '380', 'BraveSentry', '', ''],
#  ['719', '381', 'BraveSentry', '', ''],
#  ['720', '382', 'BraveSentry', '', ''],
#  ['721', '383', 'BraveSentry', '', ''],
#  ['722', '384', 'BraveSentry', '', ''],
#  ['723', '385', 'BraveSentry', '', ''],
#  ['724', '386', 'BraveSentry', '', ''],
#  ['725', '387', 'BraveSentry', '', ''],
#  ['726', '388', 'BraveSentry', '', ''],
#  ['728', '389', 'BraveSentry', '', ''],
#  ['729', '390', 'BraveSentry', '', ''],
#  ['731', '391', 'BraveSentry', '', ''],
#  ['732', '392', 'BraveSentry', '', ''],
#  ['733', '393', 'BraveSentry', '', ''],
#  ['734', '394', 'BraveSentry', '', ''],
#  ['735', '395', 'BraveSentry', '', ''],
#  ['736', '589671', 'BraveSentry', '', ''],
#  ['737', '397', 'BraveSentry', '', ''],
#  ['741', '398', 'BraveSentry', '', ''],
#  ['742', '399', 'BraveSentry', '', ''],
#  ['743', '400', 'BraveSentry', '', ''],
#  ['746', '401', 'BraveSentry', '', ''],
#  ['747', '402', 'BraveSentry', '', ''],
#  ['748', '403', 'BraveSentry', '', ''],
#  ['750', '404', 'BraveSentry', '', ''],
#  ['752', '405', 'BraveSentry', '', ''],
#  ['753', '406', 'BraveSentry', '', ''],
#  ['754', '407', 'BraveSentry', '', ''],
#  ['755', '408', 'BraveSentry', '', ''],
#  ['756', '409', 'BraveSentry', '', ''],
#  ['761', '410', 'BraveSentry', '', ''],
#  ['766', '411', 'BraveSentry', '', ''],
#  ['767', '412', 'BraveSentry', '', ''],
#  ['770', '413', 'BraveSentry', '', ''],
#  ['771', '414', 'BraveSentry', '', ''],
#  ['772', '415', 'BraveSentry', '', ''],
#  ['773', '416', 'BraveSentry', '', ''],
#  ['774', '417', 'BraveSentry', '', ''],
#  ['775', '418', 'BraveSentry', '', ''],
#  ['778', '419', 'BraveSentry', '', ''],
#  ['779', '420', 'BraveSentry', '', ''],
#  ['780', '421', 'BraveSentry', '', ''],
#  ['781', '422', 'BraveSentry', '', ''],
#  ['782', '423', 'BraveSentry', '', ''],
#  ['783', '424', 'BraveSentry', '', ''],
#  ['784', '425', 'BraveSentry', '', ''],
#  ['785', '426', 'BraveSentry', '', ''],
#  ['786', '427', 'BraveSentry', '', ''],
#  ['787', '428', 'BraveSentry', '', ''],
#  ['788', '429', 'BraveSentry', '', ''],
#  ['789', '430', 'BraveSentry', '', ''],
#  ['790', '431', 'BraveSentry', '', ''],
#  ['791', '432', 'BraveSentry', '', ''],
#  ['792', '433', 'BraveSentry', '', ''],
#  ['793', '434', 'BraveSentry', '', ''],
#  ['794', '435', 'BraveSentry', '', ''],
#  ['795', '436', 'BraveSentry', '', ''],
#  ['796', '437', 'BraveSentry', '', ''],
#  ['797', '438', 'BraveSentry', '', ''],
#  ['798', '439', 'BraveSentry', '', ''],
#  ['799', '440', 'BraveSentry', '', ''],
#  ['801', '442', 'BraveSentry', '', ''],
#  ['802', '443', 'BraveSentry', '', ''],
#  ['803', '444', 'BraveSentry', '', ''],
#  ['804', '445', 'BraveSentry', '', ''],
#  ['805', '446', 'BraveSentry', '', ''],
#  ['806', '447', 'BraveSentry', '', ''],
#  ['807', '448', 'BraveSentry', '', ''],
#  ['808', '449', 'BraveSentry', '', ''],
#  ['809', '450', 'BraveSentry', '', ''],
#  ['810', '451', 'BraveSentry', '', ''],
#  ['812', '452', 'BraveSentry', '', ''],
#  ['813', '453', 'BraveSentry', '', ''],
#  ['814', '454', 'BraveSentry', '', ''],
#  ['815', '455', 'BraveSentry', '', ''],
#  ['816', '456', 'BraveSentry', '', ''],
#  ['817', '457', 'BraveSentry', '', ''],
#  ['818', '458', 'BraveSentry', '', ''],
#  ['819', '459', 'BraveSentry', '', ''],
#  ['820', '460', 'BraveSentry', '', ''],
#  ['821', '461', 'BraveSentry', '', ''],
#  ['822', '462', 'BraveSentry', '', ''],
#  ['823', '463', 'BraveSentry', '', ''],
#  ['824', '464', 'BraveSentry', '', ''],
#  ['825', '465', 'BraveSentry', '', ''],
#  ['826', '466', 'BraveSentry', '', ''],
#  ['827', '467', 'BraveSentry', '', ''],
#  ['828', '468', 'BraveSentry', '', ''],
#  ['829', '469', 'BraveSentry', '', ''],
#  ['830', '470', 'BraveSentry', '', ''],
#  ['831', '471', 'BraveSentry', '', ''],
#  ['832', '472', 'BraveSentry', '', ''],
#  ['833', '473', 'BraveSentry', '', ''],
#  ['834', '474', 'BraveSentry', '', ''],
#  ['835', '475', 'BraveSentry', '', ''],
#  ['836', '476', 'BraveSentry', '', ''],
#  ['837', '477', 'BraveSentry', '', ''],
#  ['838', '478', 'BraveSentry', '', ''],
#  ['839', '479', 'BraveSentry', '', ''],
#  ['840', '480', 'BraveSentry', '', ''],
#  ['841', '481', 'BraveSentry', '', ''],
#  ['842', '482', 'BraveSentry', '', ''],
#  ['843', '483', 'BraveSentry', '', ''],
#  ['844', '484', 'BraveSentry', '', ''],
#  ['845', '485', 'BraveSentry', '', ''],
#  ['847', '486', 'BraveSentry', '', ''],
#  ['848', '487', 'BraveSentry', '', ''],
#  ['849', '488', 'BraveSentry', '', ''],
#  ['850', '489', 'BraveSentry', '', ''],
#  ['851', '490', 'BraveSentry', '', ''],
#  ['852', '491', 'BraveSentry', '', ''],
#  ['853', '492', 'BraveSentry', '', ''],
#  ['854', '493', 'BraveSentry', '', ''],
#  ['855', '494', 'BraveSentry', '', ''],
#  ['856', '495', 'BraveSentry', '', ''],
#  ['857', '496', 'BraveSentry', '', ''],
#  ['858', '497', 'BraveSentry', '', ''],
#  ['859', '498', 'BraveSentry', '', ''],
#  ['860', '499', 'BraveSentry', '', ''],
#  ['861', '500', 'BraveSentry', '', ''],
#  ['862', '501', 'BraveSentry', '', ''],
#  ['863', '502', 'BraveSentry', '', ''],
#  ['864', '503', 'BraveSentry', '', ''],
#  ['865', '504', 'BraveSentry', '', ''],
#  ['866', '505', 'BraveSentry', '', ''],
#  ['867', '506', 'BraveSentry', '', ''],
#  ['869', '508', 'BraveSentry', '', ''],
#  ['870', '509', 'BraveSentry', '', ''],
#  ['871', '510', 'BraveSentry', '', ''],
#  ['872', '511', 'BraveSentry', '', ''],
#  ['873', '512', 'BraveSentry', '', ''],
#  ['874', '513', 'BraveSentry', '', ''],
#  ['876', '514', 'BraveSentry', '', ''],
#  ['877', '515', 'BraveSentry', '', ''],
#  ['878', '516', 'BraveSentry', '', ''],
#  ['879', '517', 'BraveSentry', '', ''],
#  ['880', '760649', 'mramosch', '', ''],
#  ['881', '518', 'BraveSentry', '', ''],
#  ['882', '519', 'BraveSentry', '', ''],
#  ['883', '520', 'BraveSentry', '', ''],
#  ['884', '521', 'BraveSentry', '', ''],
#  ['885', '522', 'BraveSentry', '', ''],
#  ['886', '523', 'BraveSentry', '', ''],
#  ['887', '524', 'BraveSentry', '', ''],
#  ['888', '525', 'BraveSentry', '', ''],
#  ['889', '526', 'BraveSentry', '', ''],
#  ['890', '527', 'BraveSentry', '', ''],
#  ['891', '528', 'BraveSentry', '', ''],
#  ['892', '529', 'BraveSentry', '', ''],
#  ['893', '530', 'BraveSentry', '', ''],
#  ['894', '531', 'BraveSentry', '', ''],
#  ['895', '532', 'BraveSentry', '', ''],
#  ['896', '533', 'BraveSentry', '', ''],
#  ['897', '534', 'BraveSentry', '', ''],
#  ['898', '535', 'BraveSentry', '', ''],
#  ['899', '536', 'BraveSentry', '', ''],
#  ['900', '537', 'BraveSentry', '', ''],
#  ['901', '538', 'BraveSentry', '', ''],
#  ['902', '539', 'BraveSentry', '', ''],
#  ['903', '540', 'BraveSentry', '', ''],
#  ['904', '541', 'BraveSentry', '', ''],
#  ['905', '542', 'BraveSentry', '', ''],
#  ['906', '543', 'BraveSentry', '', ''],
#  ['907', '544', 'BraveSentry', '', ''],
#  ['908', '545', 'BraveSentry', '', ''],
#  ['909', '546', 'BraveSentry', '', ''],
#  ['910', '547', 'BraveSentry', '', ''],
#  ['911', '548', 'BraveSentry', '', ''],
#  ['912', '549', 'BraveSentry', '', ''],
#  ['913', '550', 'BraveSentry', '', ''],
#  ['914', '551', 'BraveSentry', '', ''],
#  ['915', '552', 'BraveSentry', '', ''],
#  ['916', '553', 'BraveSentry', '', ''],
#  ['917', '554', 'BraveSentry', '', ''],
#  ['918', '555', 'BraveSentry', '', ''],
#  ['919', '556', 'BraveSentry', '', ''],
#  ['920', '557', 'BraveSentry', '', ''],
#  ['921', '558', 'BraveSentry', '', ''],
#  ['922', '559', 'BraveSentry', '', ''],
#  ['923', '560', 'BraveSentry', '', ''],
#  ['924', '561', 'BraveSentry', '', ''],
#  ['925', '562', 'BraveSentry', '', ''],
#  ['926', '563', 'BraveSentry', '', ''],
#  ['927', '564', 'BraveSentry', '', ''],
#  ['928', '565', 'BraveSentry', '', ''],
#  ['929', '566', 'BraveSentry', '', ''],
#  ['930', '567', 'BraveSentry', '', ''],
#  ['931', '568', 'BraveSentry', '', ''],
#  ['932', '569', 'BraveSentry', '', ''],
#  ['933', '570', 'BraveSentry', '', ''],
#  ['934', '571', 'BraveSentry', '', ''],
#  ['935', '572', 'BraveSentry', '', ''],
#  ['936', '573', 'BraveSentry', '', ''],
#  ['937', '574', 'BraveSentry', '', ''],
#  ['938', '575', 'BraveSentry', '', ''],
#  ['939', '576', 'BraveSentry', '', ''],
#  ['940', '577', 'BraveSentry', '', ''],
#  ['941', '578', 'BraveSentry', '', ''],
#  ['942', '579', 'BraveSentry', '', ''],
#  ['943', '580', 'BraveSentry', '', ''],
#  ['944', '581', 'BraveSentry', '', ''],
#  ['945', '582', 'BraveSentry', '', ''],
#  ['946', '583', 'BraveSentry', '', ''],
#  ['947', '584', 'BraveSentry', '', ''],
#  ['948', '585', 'BraveSentry', '', ''],
#  ['949', '586', 'BraveSentry', '', ''],
#  ['950', '587', 'BraveSentry', '', ''],
#  ['951', '588', 'BraveSentry', '', ''],
#  ['952', '589', 'BraveSentry', '', ''],
#  ['953', '590', 'BraveSentry', '', ''],
#  ['954', '591', 'BraveSentry', '', ''],
#  ['955', '592', 'BraveSentry', '', ''],
#  ['956', '593', 'BraveSentry', '', ''],
#  ['957', '594', 'BraveSentry', '', ''],
#  ['958', '595', 'BraveSentry', '', ''],
#  ['959', '596', 'BraveSentry', '', ''],
#  ['960', '597', 'BraveSentry', '', ''],
#  ['961', '598', 'BraveSentry', '', ''],
#  ['962', '599', 'BraveSentry', '', ''],
#  ['963', '600', 'BraveSentry', '', ''],
#  ['964', '601', 'BraveSentry', '', ''],
#  ['965', '602', 'BraveSentry', '', ''],
#  ['966', '603', 'BraveSentry', '', ''],
#  ['967', '604', 'BraveSentry', '', ''],
#  ['968', '605', 'BraveSentry', '', ''],
#  ['969', '606', 'BraveSentry', '', ''],
#  ['970', '607', 'BraveSentry', '', ''],
#  ['971', '608', 'BraveSentry', '', ''],
#  ['972', '609', 'BraveSentry', '', ''],
#  ['973', '610', 'BraveSentry', '', ''],
#  ['974', '611', 'BraveSentry', '', ''],
#  ['975', '612', 'BraveSentry', '', ''],
#  ['976', '613', 'BraveSentry', '', ''],
#  ['977', '614', 'BraveSentry', '', ''],
#  ['978', '615', 'BraveSentry', '', ''],
#  ['979', '529509', 'BraveSentry', '', ''],
#  ['980', '617', 'BraveSentry', '', ''],
#  ['981', '618', 'BraveSentry', '', ''],
#  ['982', '619', 'BraveSentry', '', ''],
#  ['983', '620', 'BraveSentry', '', ''],
#  ['984', '621', 'BraveSentry', '', ''],
#  ['985', '622', 'BraveSentry', '', ''],
#  ['986', '623', 'BraveSentry', '', ''],
#  ['987', '624', 'BraveSentry', '', ''],
#  ['988', '625', 'BraveSentry', '', ''],
#  ['989', '626', 'BraveSentry', '', ''],
#  ['990', '627', 'BraveSentry', '', ''],
#  ['991', '628', 'BraveSentry', '', ''],
#  ['992', '629', 'BraveSentry', '', ''],
#  ['993', '630', 'BraveSentry', '', ''],
#  ['994', '631', 'BraveSentry', '', ''],
#  ['996', '632', 'BraveSentry', '', ''],
#  ['997', '633', 'BraveSentry', '', ''],
#  ['998', '634', 'BraveSentry', '', ''],
#  ['999', '635', 'BraveSentry', '', ''],
#  ['1001', '636', 'BraveSentry', '', ''],
#  ['1002', '637', 'BraveSentry', '', ''],
#  ['1003', '638', 'BraveSentry', '', ''],
#  ['1004', '639', 'BraveSentry', '', ''],
#  ['1005', '640', 'BraveSentry', '', ''],
#  ['1006', '641', 'BraveSentry', '', ''],
#  ['1008', '642', 'BraveSentry', '', ''],
#  ['1009', '643', 'BraveSentry', '', ''],
#  ['1010', '644', 'BraveSentry', '', ''],
#  ['1011', '645', 'BraveSentry', '', ''],
#  ['1012', '646', 'BraveSentry', '', ''],
#  ['1013', '647', 'BraveSentry', '', ''],
#  ['1014', '648', 'BraveSentry', '', ''],
#  ['1015', '649', 'BraveSentry', '', ''],
#  ['1016', '650', 'BraveSentry', '', ''],
#  ['1017', '651', 'BraveSentry', '', ''],
#  ['1018', '652', 'BraveSentry', '', ''],
#  ['1019', '653', 'BraveSentry', '', ''],
#  ['1020', '654', 'BraveSentry', '', ''],
#  ['1021', '655', 'BraveSentry', '', ''],
#  ['1022', '656', 'BraveSentry', '', ''],
#  ['1023', '657', 'BraveSentry', '', ''],
#  ['1024', '658', 'BraveSentry', '', ''],
#  ['1025', '659', 'BraveSentry', '', ''],
#  ['1026', '660', 'BraveSentry', '', ''],
#  ['1027', '661', 'BraveSentry', '', ''],
#  ['1028', '662', 'BraveSentry', '', ''],
#  ['1029', '663', 'BraveSentry', '', ''],
#  ['1030', '664', 'BraveSentry', '', ''],
#  ['1031', '665', 'BraveSentry', '', ''],
#  ['1032', '666', 'BraveSentry', '', ''],
#  ['1033', '667', 'BraveSentry', '', ''],
#  ['1034', '668', 'BraveSentry', '', ''],
#  ['1036', '669', 'BraveSentry', '', ''],
#  ['1037', '670', 'BraveSentry', '', ''],
#  ['1038', '671', 'BraveSentry', '', ''],
#  ['1039', '672', 'BraveSentry', '', ''],
#  ['1040', '673', 'BraveSentry', '', ''],
#  ['1041', '674', 'BraveSentry', '', ''],
#  ['1042', '675', 'BraveSentry', '', ''],
#  ['1043', '676', 'BraveSentry', '', ''],
#  ['1044', '677', 'BraveSentry', '', ''],
#  ['1045', '678', 'BraveSentry', '', ''],
#  ['1046', '679', 'BraveSentry', '', ''],
#  ['1047', '680', 'BraveSentry', '', ''],
#  ['1048', '681', 'BraveSentry', '', ''],
#  ['1049', '682', 'BraveSentry', '', ''],
#  ['1050', '683', 'BraveSentry', '', ''],
#  ['1051', '684', 'BraveSentry', '', ''],
#  ['1052', '685', 'BraveSentry', '', ''],
#  ['1053', '686', 'BraveSentry', '', ''],
#  ['1054', '687', 'BraveSentry', '', ''],
#  ['1055', '688', 'BraveSentry', '', ''],
#  ['1056', '689', 'BraveSentry', '', ''],
#  ['1057', '690', 'BraveSentry', '', ''],
#  ['1058', '691', 'BraveSentry', '', ''],
#  ['1059', '692', 'BraveSentry', '', ''],
#  ['1061', '693', 'BraveSentry', '', ''],
#  ['1063', '694', 'BraveSentry', '', ''],
#  ['1064', '695', 'BraveSentry', '', ''],
#  ['1065', '696', 'BraveSentry', '', ''],
#  ['1066', '697', 'BraveSentry', '', ''],
#  ['1067', '698', 'BraveSentry', '', ''],
#  ['1068', '699', 'BraveSentry', '', ''],
#  ['1069', '700', 'BraveSentry', '', ''],
#  ['1070', '701', 'BraveSentry', '', ''],
#  ['1071', '702', 'BraveSentry', '', ''],
#  ['1072', '703', 'BraveSentry', '', ''],
#  ['1073', '704', 'BraveSentry', '', ''],
#  ['1074', '705', 'BraveSentry', '', ''],
#  ['1075', '706', 'BraveSentry', '', ''],
#  ['1076', '707', 'BraveSentry', '', ''],
#  ['1077', '708', 'BraveSentry', '', ''],
#  ['1078', '709', 'BraveSentry', '', ''],
#  ['1079', '710', 'BraveSentry', '', ''],
#  ['1080', '711', 'BraveSentry', '', ''],
#  ['1081', '712', 'BraveSentry', '', ''],
#  ['1082', '713', 'BraveSentry', '', ''],
#  ['1083', '714', 'BraveSentry', '', ''],
#  ['1084', '715', 'BraveSentry', '', ''],
#  ['1085', '716', 'BraveSentry', '', ''],
#  ['1086', '717', 'BraveSentry', '', ''],
#  ['1087', '718', 'BraveSentry', '', ''],
#  ['1088', '719', 'BraveSentry', '', ''],
#  ['1089', '720', 'BraveSentry', '', ''],
#  ['1090', '721', 'BraveSentry', '', ''],
#  ['1091', '722', 'BraveSentry', '', ''],
#  ['1092', '723', 'BraveSentry', '', ''],
#  ['1093', '724', 'BraveSentry', '', ''],
#  ['1094', '725', 'BraveSentry', '', ''],
#  ['1095', '726', 'BraveSentry', '', ''],
#  ['1096', '727', 'BraveSentry', '', ''],
#  ['1097', '728', 'BraveSentry', '', ''],
#  ['1098', '729', 'BraveSentry', '', ''],
#  ['1099', '730', 'BraveSentry', '', ''],
#  ['1100', '731', 'BraveSentry', '', ''],
#  ['1101', '732', 'BraveSentry', '', ''],
#  ['1102', '733', 'BraveSentry', '', ''],
#  ['1103', '734', 'BraveSentry', '', ''],
#  ['1104', '735', 'BraveSentry', '', ''],
#  ['1105', '736', 'BraveSentry', '', ''],
#  ['1107', '737', 'BraveSentry', '', ''],
#  ['1108', '738', 'BraveSentry', '', ''],
#  ['1109', '739', 'BraveSentry', '', ''],
#  ['1110', '740', 'BraveSentry', '', ''],
#  ['1111', '741', 'BraveSentry', '', ''],
#  ['1112', '742', 'BraveSentry', '', ''],
#  ['1113', '743', 'BraveSentry', '', ''],
#  ['1114', '744', 'BraveSentry', '', ''],
#  ['1116', '672746', 'BraveSentry', '', ''],
#  ['1117', '746', 'BraveSentry', '', ''],
#  ['1118', '747', 'BraveSentry', '', ''],
#  ['1119', '748', 'BraveSentry', '', ''],
#  ['1120', '749', 'BraveSentry', '', ''],
#  ['1121', '750', 'BraveSentry', '', ''],
#  ['1122', '751', 'BraveSentry', '', ''],
#  ['1123', '752', 'BraveSentry', '', ''],
#  ['1124', '753', 'BraveSentry', '', ''],
#  ['1125', '754', 'BraveSentry', '', ''],
#  ['1126', '755', 'BraveSentry', '', ''],
#  ['1127', '756', 'BraveSentry', '', ''],
#  ['1128', '757', 'BraveSentry', '', ''],
#  ['1129', '758', 'BraveSentry', '', ''],
#  ['1130', '759', 'BraveSentry', '', ''],
#  ['1131', '760', 'BraveSentry', '', ''],
#  ['1132', '761', 'BraveSentry', '', ''],
#  ['1133', '762', 'BraveSentry', '', ''],
#  ['1135', '763', 'BraveSentry', '', ''],
#  ['1136', '764', 'BraveSentry', '', ''],
#  ['1137', '765', 'BraveSentry', '', ''],
#  ['1139', '766', 'BraveSentry', '', ''],
#  ['1140', '767', 'BraveSentry', '', ''],
#  ['1141', '768', 'BraveSentry', '', ''],
#  ['1142', '769', 'BraveSentry', '', ''],
#  ['1143', '770', 'BraveSentry', '', ''],
#  ['1144', '771', 'BraveSentry', '', ''],
#  ['1145', '772', 'BraveSentry', '', ''],
#  ['1146', '773', 'BraveSentry', '', ''],
#  ['1148', '774', 'BraveSentry', '', ''],
#  ['1149', '775', 'BraveSentry', '', ''],
#  ['1150', '776', 'BraveSentry', '', ''],
#  ['1151', '777', 'BraveSentry', '', ''],
#  ['1153', '778', 'BraveSentry', '', ''],
#  ['1154', '779', 'BraveSentry', '', ''],
#  ['1155', '780', 'BraveSentry', '', ''],
#  ['1156', '781', 'BraveSentry', '', ''],
#  ['1157', '782', 'BraveSentry', '', ''],
#  ['1158', '783', 'BraveSentry', '', ''],
#  ['1159', '784', 'BraveSentry', '', ''],
#  ['1160', '785', 'BraveSentry', '', ''],
#  ['1161', '786', 'BraveSentry', '', ''],
#  ['1163', '787', 'BraveSentry', '', ''],
#  ['1164', '788', 'BraveSentry', '', ''],
#  ['1165', '789', 'BraveSentry', '', ''],
#  ['1166', '790', 'BraveSentry', '', ''],
#  ['1167', '791', 'BraveSentry', '', ''],
#  ['1168', '792', 'BraveSentry', '', ''],
#  ['1169', '793', 'BraveSentry', '', ''],
#  ['1170', '794', 'BraveSentry', '', ''],
#  ['1171', '795', 'BraveSentry', '', ''],
#  ['1172',
#   '566400',
#   'driini',
#   'CC BY-NC 4.0',
#   'https://tatoeba.org/deu/user/profile/driini'],
#  ['1173', '796', 'BraveSentry', '', ''],
#  ['1174', '797', 'BraveSentry', '', ''],
#  ['1175', '798', 'BraveSentry', '', ''],
#  ['1176', '799', 'BraveSentry', '', ''],
#  ['1177', '800', 'BraveSentry', '', ''],
#  ['1178', '801', 'BraveSentry', '', ''],
#  ['1179', '802', 'BraveSentry', '', ''],
#  ['1180', '803', 'BraveSentry', '', ''],
#  ['1182', '804', 'BraveSentry', '', ''],
#  ['1183', '805', 'BraveSentry', '', ''],
#  ['1184', '806', 'BraveSentry', '', ''],
#  ['1185', '807', 'BraveSentry', '', ''],
#  ['1186', '808', 'BraveSentry', '', ''],
#  ['1187', '809', 'BraveSentry', '', ''],
#  ['1188', '810', 'BraveSentry', '', ''],
#  ['1189', '811', 'BraveSentry', '', ''],
#  ['1191', '812', 'BraveSentry', '', ''],
#  ['1192', '813', 'BraveSentry', '', ''],
#  ['1193', '814', 'BraveSentry', '', ''],
#  ['1194', '815', 'BraveSentry', '', ''],
#  ['1195', '816', 'BraveSentry', '', ''],
#  ['1196', '817', 'BraveSentry', '', ''],
#  ['1197', '818', 'BraveSentry', '', ''],
#  ['1198', '819', 'BraveSentry', '', ''],
#  ['1199', '820', 'BraveSentry', '', ''],
#  ['1200', '821', 'BraveSentry', '', ''],
#  ['1201', '822', 'BraveSentry', '', ''],
#  ['1202', '823', 'BraveSentry', '', ''],
#  ['1203', '824', 'BraveSentry', '', ''],
#  ['1205', '825', 'BraveSentry', '', ''],
#  ['1206', '826', 'BraveSentry', '', ''],
#  ['1207', '827', 'BraveSentry', '', ''],
#  ['1208', '828', 'BraveSentry', '', ''],
#  ['1209', '829', 'BraveSentry', '', ''],
#  ['1210', '830', 'gretelen', 'CC BY-NC 4.0', ''],
#  ['1212', '831', 'BraveSentry', '', ''],
#  ['1213', '832', 'BraveSentry', '', ''],
#  ['1214', '833', 'BraveSentry', '', ''],
#  ['1215', '834', 'BraveSentry', '', ''],
#  ['1217', '835', 'BraveSentry', '', ''],
#  ['1218', '836', 'BraveSentry', '', ''],
#  ['1219', '837', 'BraveSentry', '', ''],
#  ['1220', '838', 'BraveSentry', '', ''],
#  ['1221', '839', 'BraveSentry', '', ''],
#  ['1222', '840', 'BraveSentry', '', ''],
#  ['1223', '841', 'BraveSentry', '', ''],
#  ['1224', '842', 'BraveSentry', '', ''],
#  ['1225', '843', 'BraveSentry', '', ''],
#  ['1226', '844', 'BraveSentry', '', ''],
#  ['1227', '845', 'BraveSentry', '', ''],
#  ['1228', '846', 'BraveSentry', '', ''],
#  ['1229', '847', 'BraveSentry', '', ''],
#  ['1230', '848', 'BraveSentry', '', ''],
#  ['1231', '849', 'BraveSentry', '', ''],
#  ['1232', '850', 'BraveSentry', '', ''],
#  ['1233', '851', 'BraveSentry', '', ''],
#  ['1234', '852', 'BraveSentry', '', ''],
#  ['1235', '853', 'BraveSentry', '', ''],
#  ['1236', '854', 'BraveSentry', '', ''],
#  ['1237', '855', 'BraveSentry', '', ''],
#  ['1238', '856', 'BraveSentry', '', ''],
#  ['1239', '857', 'BraveSentry', '', ''],
#  ['1240', '858', 'BraveSentry', '', ''],
#  ['1241', '859', 'BraveSentry', '', ''],
#  ['1242', '860', 'BraveSentry', '', ''],
#  ['1243', '861', 'BraveSentry', '', ''],
#  ['1244', '862', 'BraveSentry', '', ''],
#  ['1245', '863', 'BraveSentry', '', ''],
#  ['1246', '864', 'BraveSentry', '', ''],
#  ['1248', '865', 'BraveSentry', '', ''],
#  ['1249', '866', 'BraveSentry', '', ''],
#  ['1250', '867', 'BraveSentry', '', ''],
#  ['1252', '868', 'BraveSentry', '', ''],
#  ['1253', '869', 'BraveSentry', '', ''],
#  ['1254', '870', 'BraveSentry', '', ''],
#  ['1255', '871', 'BraveSentry', '', ''],
#  ['1256', '872', 'BraveSentry', '', ''],
#  ['1257', '873', 'BraveSentry', '', ''],
#  ['1258', '874', 'BraveSentry', '', ''],
#  ['1259', '875', 'BraveSentry', '', ''],
#  ['1260', '876', 'BraveSentry', '', ''],
#  ['1261', '877', 'BraveSentry', '', ''],
#  ['1262', '878', 'BraveSentry', '', ''],
#  ['1263', '879', 'BraveSentry', '', ''],
#  ['1264', '880', 'BraveSentry', '', ''],
#  ['1266', '881', 'BraveSentry', '', ''],
#  ['1267', '882', 'BraveSentry', '', ''],
#  ['1268', '883', 'BraveSentry', '', ''],
#  ['1269', '884', 'BraveSentry', '', ''],
#  ['1270', '885', 'BraveSentry', '', ''],
#  ['1271', '886', 'BraveSentry', '', ''],
#  ['1272', '887', 'BraveSentry', '', ''],
#  ['1273', '888', 'BraveSentry', '', ''],
#  ['1274', '889', 'BraveSentry', '', ''],
#  ['1275', '890', 'BraveSentry', '', ''],
#  ['1276', '891', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1277', '892', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1283', '893', 'Nero', '', ''],
#  ['1284', '894', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1286',
#   '598384',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1287', '895', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1288', '896', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1290', '897', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1291', '898', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1292', '899', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1294', '900', 'Nero', '', ''],
#  ['1295', '901', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1296', '902', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1298',
#   '879060',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1299',
#   '900107',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1302', '903', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1304',
#   '620894',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1305', '904', 'Nero', '', ''],
#  ['1308', '905', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1308', '1197605', 'cblanken', 'CC BY-NC 4.0', ''],
#  ['1309', '906', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1311', '907', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1311', '1197606', 'cblanken', 'CC BY-NC 4.0', ''],
#  ['1312', '908', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1313', '909', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1314',
#   '593938',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1315', '910', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1316', '911', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1317', '912', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1318', '913', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1319', '914', 'Nero', '', ''],
#  ['1322', '915', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1326', '916', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1329', '917', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1330', '918', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1333', '919', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1334', '1197607', 'cblanken', 'CC BY-NC 4.0', ''],
#  ['1335', '920', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1337', '921', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1339', '922', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1344', '923', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1345',
#   '340475',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1347', '924', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1348',
#   '486124',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1353', '925', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1354', '926', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1355', '927', 'Nero', '', ''],
#  ['1356', '928', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1357', '929', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1358',
#   '643442',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1359', '930', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1360', '931', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1361', '932', 'Nero', '', ''],
#  ['1364',
#   '781900',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1366', '933', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1368', '934', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1370',
#   '943200',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1372', '935', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1373', '936', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1374', '1197609', 'cblanken', 'CC BY-NC 4.0', ''],
#  ['1375',
#   '944531',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1376', '937', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1378',
#   '374956',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1379', '938', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1380', '939', 'Nero', '', ''],
#  ['1383', '940', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1385', '941', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1386', '942', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1387', '943', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1388',
#   '595626',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1390', '944', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1391', '945', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1392', '946', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1393', '947', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1394', '948', 'Nero', '', ''],
#  ['1395', '949', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1397', '950', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1398', '951', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1399', '952', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1402', '953', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1403', '954', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1407',
#   '800664',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1408', '955', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1414', '956', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1417',
#   '696374',
#   'CK',
#   'CC BY-NC-ND 3.0',
#   'http://www.manythings.org/tatoeba'],
#  ['1419', '957', 'Nero', '', ''],
#  ['1420', '958', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1421', '959', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ['1423', '960', 'CK', 'CC BY-NC-ND 3.0', 'http://www.manythings.org/tatoeba'],
#  ...]

# %%
def get_audio_id(sentence_id, audio_data):
    for xs in audio_data:
        if xs[0] == sentence_id:
            return xs[1]
    return ''

# %%
for word in vocab:
    sentence1_id = vocab[word]['sentence1_id_de']
    audio_id = get_audio_id(sentence1_id, audio_data)
    vocab[word]['sentence1_audio_id'] = audio_id
    
    sentence2_id = vocab[word]['sentence2_id_de']
    if sentence2_id:
        audio_id = get_audio_id(sentence2_id, audio_data)
        vocab[word]['sentence1_audio_id'] = audio_id

# %%
vocab
# Out:
# {'der Arzt, die Ärzte': {'word_en': 'doctor (male)',
#   'sentence1_id_de': '458886',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ist sein Vater Arzt?',
#   'sentence2_text': '',
#   'translation1_en': 'Is his father a doctor?',
#   'sentence1_audio_id': '35269'},
#  'die Ärztin, die Ärztinnen': {'word_en': 'doctor (female)',
#   'sentence1_id_de': '428477',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ist sie Ärztin?',
#   'sentence2_text': '',
#   'translation1_en': 'Is she a doctor?',
#   'sentence1_audio_id': '33768'},
#  'der Babysitter, die Babysitter': {'word_en': 'babysitter (male)',
#   'sentence1_id_de': '3751325',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ich benötige keinen Babysitter.',
#   'sentence2_text': '',
#   'sentence1_audio_id': ''},
#  'die Babysitterin, die Babysitterinnen': {'word_en': 'babysitter (female)',
#   'sentence1_id_de': '8074468',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Als Jugendliche jobbte Maria als Babysitterin.',
#   'sentence2_text': '',
#   'translation1_en': 'Mary worked as a babysitter when she was a teenager.',
#   'sentence1_audio_id': ''},
#  'beginnen': {'word_en': 'to begin; to start',
#   'sentence1_id_de': '722917',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Sollen wir beginnen?',
#   'sentence2_text': '',
#   'translation1_en': 'Shall we begin?',
#   'translation2_en': 'Shall we start?',
#   'sentence1_audio_id': '44139'},
#  'krank': {'word_en': 'sick; ill',
#   'sentence1_id_de': '722917',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Sollen wir beginnen?',
#   'sentence2_text': '',
#   'translation1_en': 'Shall we begin?',
#   'translation2_en': 'Shall we start?',
#   'sentence1_audio_id': '44139'},
#  'die Lösung, die Lösungen': {'word_en': 'solution',
#   'sentence1_id_de': '1205',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Es gibt keine Lösung.',
#   'sentence2_text': '',
#   'translation1_en': "There isn't any solution.",
#   'translation2_en': 'There is no solution.',
#   'sentence1_audio_id': '825'},
#  'die Mittagspause, die Mittagspausen': {'word_en': 'lunch break',
#   'sentence1_id_de': '7552388',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Meine Mittagspause ist fast vorbei.',
#   'sentence2_text': '',
#   'translation1_en': "My lunch break's almost over.",
#   'sentence1_audio_id': ''},
#  'die Schule, die Schulen': {'word_en': 'school',
#   'sentence1_id_de': '135753',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Das ist unsere Schule.',
#   'sentence2_text': '',
#   'translation1_en': 'That is our school.',
#   'sentence1_audio_id': '12482'},
#  'der Tag, die Tage': {'word_en': 'day',
#   'sentence1_id_de': '454009',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Die Tage werden länger.',
#   'sentence2_text': '',
#   'translation1_en': 'The days are growing longer.',
#   'translation2_en': 'The days are getting longer.',
#   'sentence1_audio_id': '566582'},
#  'der Termin, die Termine': {'word_en': 'appointment',
#   'sentence1_id_de': '477555',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Ich habe einen Termin beim Arzt.',
#   'sentence2_text': '',
#   'translation1_en': 'I have an appointment with the doctor.',
#   'translation2_en': "I have a doctor's appointment.",
#   'translation3_en': "I've got a doctor's appointment.",
#   'sentence1_audio_id': '566949'},
#  'das Training, die Trainings': {'word_en': 'training; workout; practice',
#   'sentence1_id_de': '1166392',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Rennen ist ein gutes Training.',
#   'sentence2_text': '',
#   'sentence1_audio_id': ''},
#  'die Uni, die Unis': {'word_en': 'University; college',
#   'sentence1_id_de': '8493305',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Wo ist eure Uni?',
#   'sentence2_text': '',
#   'translation1_en': "Where's your university?",
#   'translation2_en': "Where's your uni?",
#   'sentence1_audio_id': ''},
#  'wann': {'word_en': 'when',
#   'sentence1_id_de': '766384',
#   'sentence2_id_de': '',
#   'sentence1_text': 'Wann arbeitest du?',
#   'sentence2_text': '',
#   'translation1_en': 'When do you work?',
#   'sentence1_audio_id': '394275'}}

# %% [markdown]
# ## Download the audio files

# %%
AUDIO_DIRECTORY = './days_and_times/emmas-tag'

# %%
def download_mp3(audio_id,
                 audio_url_template='https://tatoeba.org/audio/download/{0}',
                 audio_directory=AUDIO_DIRECTORY):
    request_url = audio_url_template.format(audio_id)
    mp3data_request = requests.get(request_url)
    mp3data = mp3data_request.content
    with open(f'{audio_directory}/{audio_id}.mp3', 'wb') as mp3file:
        mp3file.write(mp3data)

# %%
for word in vocab:
    audio1_id = vocab[word]['sentence1_audio_id']
    if audio1_id:
        download_mp3(audio1_id)
    try:
        audio2_id = vocab[word]['sentence2_audio_id']
        download_mp3(audio2_id)
    except KeyError:
        continue
