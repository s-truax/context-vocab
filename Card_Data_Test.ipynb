# %%
import pandas as pd
import requests

# %% [markdown]
# ## Audio Sentence Processing

# %%
ingest = pd.read_table('sentences_with_audio.csv',
                       names=['sentence_id',
                              'audio_id',
                              'username',
                              'license',
                              'attribution_url'])

# %%
ingest
# Out:
#          sentence_id  audio_id    username       license  \
# 0                 61         1  fucongcong           NaN
# 1                 68         2  fucongcong           NaN
# 2                 78    754915    mramosch           NaN
# 3                 85    566395      driini  CC BY-NC 4.0
# 4                 88    592881      driini  CC BY-NC 4.0
# ...              ...       ...         ...           ...
# 1195633     12858087   1238345       PaulP  CC BY-NC 4.0
# 1195634     12865980   1239468       PaulP  CC BY-NC 4.0
# 1195635     12867905   1239469       PaulP  CC BY-NC 4.0
# 1195636     12875115   1239470       PaulP  CC BY-NC 4.0
# 1195637     12878908   1239967       PaulP  CC BY-NC 4.0
#
#                                      attribution_url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3        https://tatoeba.org/deu/user/profile/driini
# 4        https://tatoeba.org/deu/user/profile/driini
# ...                                              ...
# 1195633                                          NaN
# 1195634                                          NaN
# 1195635                                          NaN
# 1195636                                          NaN
# 1195637                                          NaN
#
# [1195638 rows x 5 columns]

# %%
vocab_list = pd.read_table('vocab_basket.tsv',
                           names=['sentence_id',
                                  'text',
                                  'translation'])

# %%
vocab_list
# Out:
#    sentence_id                            text               translation
# 0      1729338         Ich nehme Geschenke an.           I accept gifts.
# 1      1907195            Es war ein Geschenk.            It was a gift.
# 2      2776108             Tom bleibt bei uns.        Tom stays with us.
# 3      2776108             Tom bleibt bei uns.    Tom will stay with us.
# 4      6960575  Tom akzeptierte mein Geschenk.  Tom accepted my present.
# 5      7636008  Tom schickte mir ein Geschenk.    Tom sent me a present.

# %%
# using pd.merge can cause problems if there are NaN values.
# So maybe double check your understanding of what's going on here.
with_audio = pd.merge(ingest, vocab_list, on='sentence_id', how='inner')

# %%
with_audio
# Out:
#    sentence_id  audio_id  username       license attribution_url  \
# 0      1907195     87415  gretelen  CC BY-NC 4.0             NaN
# 1      2776108    166329      Yeti     CC BY 4.0             NaN
# 2      2776108    166329      Yeti     CC BY 4.0             NaN
# 3      6960575    484943  moskytoo  CC BY-NC 4.0             NaN
# 4      7636008    757809  mramosch           NaN             NaN
#
#                              text               translation
# 0            Es war ein Geschenk.            It was a gift.
# 1             Tom bleibt bei uns.        Tom stays with us.
# 2             Tom bleibt bei uns.    Tom will stay with us.
# 3  Tom akzeptierte mein Geschenk.  Tom accepted my present.
# 4  Tom schickte mir ein Geschenk.    Tom sent me a present.

# %%
# Trying to do this with the .join method.
ingest_reindex = ingest.set_index('sentence_id')
vocab_reindex = vocab_list.set_index('sentence_id')

# %%
vocab_reindex
# Out:
#                                        text               translation
# sentence_id
# 1729338             Ich nehme Geschenke an.           I accept gifts.
# 1907195                Es war ein Geschenk.            It was a gift.
# 2776108                 Tom bleibt bei uns.        Tom stays with us.
# 2776108                 Tom bleibt bei uns.    Tom will stay with us.
# 6960575      Tom akzeptierte mein Geschenk.  Tom accepted my present.
# 7636008      Tom schickte mir ein Geschenk.    Tom sent me a present.

# %%
ingest_reindex
# Out:
#              audio_id    username       license  \
# sentence_id
# 61                  1  fucongcong           NaN
# 68                  2  fucongcong           NaN
# 78             754915    mramosch           NaN
# 85             566395      driini  CC BY-NC 4.0
# 88             592881      driini  CC BY-NC 4.0
# ...               ...         ...           ...
# 12858087      1238345       PaulP  CC BY-NC 4.0
# 12865980      1239468       PaulP  CC BY-NC 4.0
# 12867905      1239469       PaulP  CC BY-NC 4.0
# 12875115      1239470       PaulP  CC BY-NC 4.0
# 12878908      1239967       PaulP  CC BY-NC 4.0
#
#                                          attribution_url
# sentence_id
# 61                                                   NaN
# 68                                                   NaN
# 78                                                   NaN
# 85           https://tatoeba.org/deu/user/profile/driini
# 88           https://tatoeba.org/deu/user/profile/driini
# ...                                                  ...
# 12858087                                             NaN
# 12865980                                             NaN
# 12867905                                             NaN
# 12875115                                             NaN
# 12878908                                             NaN
#
# [1195638 rows x 4 columns]

# %%
with_audio_reindex = ingest_reindex.join(vocab_reindex, how='inner')

# %%
with_audio_reindex
# Out:
#              audio_id  username       license attribution_url  \
# sentence_id
# 1907195         87415  gretelen  CC BY-NC 4.0             NaN
# 2776108        166329      Yeti     CC BY 4.0             NaN
# 2776108        166329      Yeti     CC BY 4.0             NaN
# 6960575        484943  moskytoo  CC BY-NC 4.0             NaN
# 7636008        757809  mramosch           NaN             NaN
#
#                                        text               translation
# sentence_id
# 1907195                Es war ein Geschenk.            It was a gift.
# 2776108                 Tom bleibt bei uns.        Tom stays with us.
# 2776108                 Tom bleibt bei uns.    Tom will stay with us.
# 6960575      Tom akzeptierte mein Geschenk.  Tom accepted my present.
# 7636008      Tom schickte mir ein Geschenk.    Tom sent me a present.

# %% [markdown]
# ## Get the audio files

# %%
audio_url_template = 'https://tatoeba.org/audio/download/{0}'

# %%
for audio_id in with_audio_reindex['audio_id']:
    request_url = audio_url_template.format(audio_id)
    mp3data_request = requests.get(request_url)
    mp3data = mp3data_request.content
    with open('{0}.mp3'.format(audio_id), 'wb') as mp3file:
        mp3file.write(mp3data)
